# %%
# importing all the requuired packages

import pandas as pd
import numpy as np
from sklearn.neighbors import KNeighborsRegressor # regression model
from sklearn.model_selection import train_test_split

# %%
# grabbing the dataset of kaggle
los_data = pd.read_csv("./Data/kaggle_los.csv")
los_data.head()
# Out:
# C:\Users\Deepjyoti\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   Health Service Area Hospital County  Operating Certificate Number  \
# 0          Western NY     Cattaraugus                      401001.0
# 1          Western NY     Cattaraugus                      401001.0
# 2          Western NY     Cattaraugus                      401001.0
# 3          Western NY     Cattaraugus                      401001.0
# 4          Western NY      Chautauqua                      602001.0
#
#    Facility Id                  Facility Name Age Group Zip Code - 3 digits  \
# 0         66.0         Olean General Hospital  50 to 69                 147
# 1         66.0         Olean General Hospital  18 to 29                 147
# 2         66.0         Olean General Hospital  30 to 49                 147
# 3         66.0         Olean General Hospital  50 to 69                 147
# 4        103.0  Woman's Christian Association  50 to 69                 147
#
#   Gender   Race          Ethnicity     ...     Payment Typology 2  \
# 0      F  White  Not Span/Hispanic     ...                    NaN
# 1      F  White  Not Span/Hispanic     ...                    NaN
# 2      M  White  Not Span/Hispanic     ...                    NaN
# 3      F  White  Not Span/Hispanic     ...                    NaN
# 4      M  White  Not Span/Hispanic     ...                    NaN
#
#   Payment Typology 3 Attending Provider License Number  \
# 0                NaN                          267162.0
# 1                NaN                          275408.0
# 2                NaN                          267162.0
# 3                NaN                          271326.0
# 4                NaN                          243034.0
#
#    Operating Provider License Number  Other Provider License Number  \
# 0                                NaN                            NaN
# 1                                NaN                            NaN
# 2                                NaN                            NaN
# 3                                NaN                            NaN
# 4                                NaN                            NaN
#
#   Birth Weight  Abortion Edit Indicator Emergency Department Indicator  \
# 0            0                        N                              Y
# 1            0                        N                              Y
# 2            0                        N                              Y
# 3            0                        N                              Y
# 4            0                        N                              Y
#
#    Total Charges Total Costs
# 0       $5620.00    $4561.28
# 1       $7404.18    $6933.94
# 2       $7931.28    $7154.85
# 3      $11304.44    $4584.11
# 4       $8330.50    $4361.74
#
# [5 rows x 37 columns]

# %%
# creating a DataFrame
data = pd.DataFrame(los_data).dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)

# %%
np.random.seed()

# %%
data.sample(5)
# Out:
#        Health Service Area Hospital County  Operating Certificate Number  \
# 99111           Western NY            Erie                     1401013.0
# 117616          Western NY            Erie                     1404000.0
# 365823          Central NY           Lewis                     2424700.0
# 3463            Western NY        Allegany                      228000.0
# 914909       New York City           Bronx                     7000001.0
#
#         Facility Id                                      Facility Name  \
# 99111         218.0                        Sisters of Charity Hospital
# 117616        267.0                             Kenmore Mercy Hospital
# 365823        383.0                      Lewis County General Hospital
# 3463           39.0  Memorial Hosp of Wm F & Gertrude F Jones A/K/A...
# 914909       1164.0    Bronx-Lebanon Hospital Center - Fulton Division
#
#           Age Group Zip Code - 3 digits Gender        Race          Ethnicity  \
# 99111   70 or Older                 140      M       White  Not Span/Hispanic
# 117616     50 to 69                 141      F       White  Not Span/Hispanic
# 365823     30 to 49                 133      F       White  Not Span/Hispanic
# 3463       18 to 29                 148      F       White  Not Span/Hispanic
# 914909     50 to 69                 104      F  Other Race            Unknown
#
#            ...     Payment Typology 2      Payment Typology 3  \
# 99111      ...               Medicare  Blue Cross/Blue Shield
# 117616     ...               Medicare  Blue Cross/Blue Shield
# 365823     ...               Self-Pay                Self-Pay
# 3463       ...               Self-Pay                Self-Pay
# 914909     ...               Medicare                Medicaid
#
#        Attending Provider License Number  Operating Provider License Number  \
# 99111                           163910.0                         20002491.0
# 117616                          229921.0                           164085.0
# 365823                          167146.0                           167146.0
# 3463                            196988.0                           196988.0
# 914909                        90270405.0                         90270405.0
#
#         Other Provider License Number Birth Weight  Abortion Edit Indicator  \
# 99111                        184241.0            0                        N
# 117616                       229921.0            0                        N
# 365823                       115469.0            0                        N
# 3463                         247101.0            0                        N
# 914909                     90270405.0            0                        N
#
#        Emergency Department Indicator  Total Charges Total Costs
# 99111                               Y      $37868.69   $19426.97
# 117616                              Y      $20599.12    $6233.69
# 365823                              N      $16986.75   $12826.71
# 3463                                N      $10844.25    $5252.32
# 914909                              Y      $45880.22   $45049.03
#
# [5 rows x 37 columns]

# %%
data.tail()
# Out:
#         Health Service Area Hospital County  Operating Certificate Number  \
# 2254893         Long Island         Suffolk                     5149000.0
# 2254970         Long Island         Suffolk                     5149000.0
# 2254976         Long Island         Suffolk                     5149000.0
# 2255087         Long Island         Suffolk                     5149000.0
# 2255088         Long Island         Suffolk                     5149000.0
#
#          Facility Id                                      Facility Name  \
# 2254893        895.0  John T Mather Memorial Hospital of Port Jeffer...
# 2254970        895.0  John T Mather Memorial Hospital of Port Jeffer...
# 2254976        895.0  John T Mather Memorial Hospital of Port Jeffer...
# 2255087        895.0  John T Mather Memorial Hospital of Port Jeffer...
# 2255088        895.0  John T Mather Memorial Hospital of Port Jeffer...
#
#            Age Group Zip Code - 3 digits Gender   Race          Ethnicity  \
# 2254893     50 to 69                 117      M  White  Not Span/Hispanic
# 2254970     30 to 49                 119      F  White  Not Span/Hispanic
# 2254976  70 or Older                 117      M  White  Not Span/Hispanic
# 2255087  70 or Older                 117      M  White  Not Span/Hispanic
# 2255088  70 or Older                 117      F  White  Not Span/Hispanic
#
#             ...     Payment Typology 2        Payment Typology 3  \
# 2254893     ...               Medicare                  Medicare
# 2254970     ...               Medicare                  Medicaid
# 2254976     ...               Medicare  Private Health Insurance
# 2255087     ...               Medicare  Private Health Insurance
# 2255088     ...               Medicare  Private Health Insurance
#
#         Attending Provider License Number  Operating Provider License Number  \
# 2254893                          202072.0                           202072.0
# 2254970                          276398.0                           272770.0
# 2254976                          278933.0                           202633.0
# 2255087                          210655.0                           213007.0
# 2255088                          236434.0                           175861.0
#
#          Other Provider License Number Birth Weight  Abortion Edit Indicator  \
# 2254893                       195773.0            0                        N
# 2254970                     90015420.0            0                        N
# 2254976                       261820.0            0                        N
# 2255087                       225020.0            0                        N
# 2255088                       236434.0            0                        N
#
#         Emergency Department Indicator  Total Charges Total Costs
# 2254893                              Y      $72645.79   $19718.92
# 2254970                              Y      $36426.58    $8918.25
# 2254976                              Y     $104366.20   $27021.57
# 2255087                              Y      $79229.90   $28512.62
# 2255088                              Y      $11920.33    $3110.73
#
# [5 rows x 37 columns]

# %%
print("Data types:\n")
data.dtypes
# Out:
# Data types:
# Health Service Area                     object
# Hospital County                         object
# Operating Certificate Number           float64
# Facility Id                            float64
# Facility Name                           object
# Age Group                               object
# Zip Code - 3 digits                     object
# Gender                                  object
# Race                                    object
# Ethnicity                               object
# Length of Stay                          object
# Type of Admission                       object
# Patient Disposition                     object
# Discharge Year                           int64
# CCS Diagnosis Code                       int64
# CCS Diagnosis Description               object
# CCS Procedure Code                       int64
# CCS Procedure Description               object
# APR DRG Code                             int64
# APR DRG Description                     object
# APR MDC Code                             int64
# APR MDC Description                     object
# APR Severity of Illness Code             int64
# APR Severity of Illness Description     object
# APR Risk of Mortality                   object
# APR Medical Surgical Description        object
# Payment Typology 1                      object
# Payment Typology 2                      object
# Payment Typology 3                      object
# Attending Provider License Number      float64
# Operating Provider License Number      float64
# Other Provider License Number          float64
# Birth Weight                             int64
# Abortion Edit Indicator                 object
# Emergency Department Indicator          object
# Total Charges                           object
# Total Costs                             object
# dtype: object

# %%
#column name change
data.columns=[each.replace(" ","_") for each in data.columns]

#remove dollar sign
data.Total_Charges=[each.replace("$","") for each in data.Total_Charges]
data.Total_Costs=[each.replace("$","") for each in data.Total_Costs]

#lets convert object to float
data["Total_Charges"]=data["Total_Charges"].astype('float')
data["Total_Costs"]=data["Total_Costs"].astype('float')

#Delete the + sign
data.Length_of_Stay=[each.replace("+","") if(each=="120 +") else each for each in data.Length_of_Stay]
#lets convert object to int
data["Length_of_Stay"]=data["Length_of_Stay"].astype('int')

# %%
data.dtypes
# Out:
# Health_Service_Area                     object
# Hospital_County                         object
# Operating_Certificate_Number           float64
# Facility_Id                            float64
# Facility_Name                           object
# Age_Group                               object
# Zip_Code_-_3_digits                     object
# Gender                                  object
# Race                                    object
# Ethnicity                               object
# Length_of_Stay                           int32
# Type_of_Admission                       object
# Patient_Disposition                     object
# Discharge_Year                           int64
# CCS_Diagnosis_Code                       int64
# CCS_Diagnosis_Description               object
# CCS_Procedure_Code                       int64
# CCS_Procedure_Description               object
# APR_DRG_Code                             int64
# APR_DRG_Description                     object
# APR_MDC_Code                             int64
# APR_MDC_Description                     object
# APR_Severity_of_Illness_Code             int64
# APR_Severity_of_Illness_Description     object
# APR_Risk_of_Mortality                   object
# APR_Medical_Surgical_Description        object
# Payment_Typology_1                      object
# Payment_Typology_2                      object
# Payment_Typology_3                      object
# Attending_Provider_License_Number      float64
# Operating_Provider_License_Number      float64
# Other_Provider_License_Number          float64
# Birth_Weight                             int64
# Abortion_Edit_Indicator                 object
# Emergency_Department_Indicator          object
# Total_Charges                          float64
# Total_Costs                            float64
# dtype: object

# %%
data['Length_of_Stay']
# Out:
# 3310        5
# 3311        2
# 3312        3
# 3316        5
# 3335        4
# 3341        2
# 3371        2
# 3377        4
# 3410        4
# 3455        4
# 3461        4
# 3463        3
# 3464        9
# 3473       26
# 3476        3
# 3477        2
# 3478        1
# 3493        3
# 3497        2
# 3503        1
# 3512        3
# 3522        2
# 3533        3
# 3558        5
# 3583        3
# 3585        3
# 3587        4
# 3606        3
# 3634        3
# 3645        3
#            ..
# 2254140     9
# 2254162     7
# 2254216     4
# 2254233    10
# 2254255     4
# 2254260    10
# 2254266    15
# 2254267     3
# 2254268     9
# 2254288     3
# 2254380    12
# 2254404     6
# 2254450     5
# 2254475    10
# 2254488     7
# 2254502    14
# 2254628     2
# 2254649     5
# 2254669    23
# 2254675     6
# 2254684     4
# 2254685     3
# 2254737     3
# 2254793     9
# 2254800     5
# 2254893     9
# 2254970     2
# 2254976    13
# 2255087     8
# 2255088     1
# Name: Length_of_Stay, Length: 8160, dtype: int32

# %%
#we found out how many Type of Admission
print("Type of Admission in Dataset:\n")
print(data.Type_of_Admission.unique())
#we found out how many Age group
print("\n\nAge Group in Dataset:\n")
print(data.Age_Group.unique())
#we found out how many ARP Risk of Mortality
print("\n\nARP Risk of Mortality:\n")
print(data.APR_Risk_of_Mortality.unique())
#we found out how many hospital country in our data
print("\n\nHospital Country in Dataset:\n")
print("There are {} different values\n".format(len(data.Hospital_County.unique())))
print(data.Hospital_County.unique())
#we found out how many ARP MDC Description
print("\n\nARP MDC Description(disease diagnosis) in Dataset:\n")
print("There are {} different values\n".format(len(data.APR_MDC_Description.unique())))
print(data.APR_MDC_Description.unique())
print("\n\nThere are {} different values\n".format(len(data.Emergency_Department_Indicator.unique())))
print(data.Emergency_Department_Indicator.unique())
# Out:
# Type of Admission in Dataset:
#
# ['Elective' 'Urgent' 'Emergency' 'Newborn' 'Not Available' 'Trauma']
#
#
# Age Group in Dataset:
#
# ['50 to 69' '30 to 49' '18 to 29' '70 or Older' '0 to 17']
#
#
# ARP Risk of Mortality:
#
# ['Minor' 'Moderate' 'Extreme' 'Major']
#
#
# Hospital Country in Dataset:
#
# There are 28 different values
#
# ['Allegany' 'Cattaraugus' 'Chautauqua' 'Erie' 'Genesee' 'Niagara' 'Monroe'
#  'Ontario' 'Steuben' 'Cayuga' 'Herkimer' 'Lewis' 'Madison' 'Oneida'
#  'St Lawrence' 'Albany' 'Fulton' 'Montgomery' 'Rensselaer' 'Schenectady'
#  'Dutchess' 'Putnam' 'Ulster' 'Westchester' 'Bronx' 'Manhattan' 'Nassau'
#  'Suffolk']
#
#
# ARP MDC Description(disease diagnosis) in Dataset:
#
# There are 25 different values
#
# ['Diseases and Disorders of the Digestive System'
#  'Pregnancy, Childbirth and the Puerperium'
#  'Diseases and Disorders of the Female Reproductive System'
#  'Infectious and Parasitic Diseases, Systemic or Unspecified Sites'
#  'Diseases and Disorders of the Musculoskeletal System and Conn Tissue'
#  'Diseases and Disorders of the Respiratory System'
#  'Diseases and Disorders of the Hepatobiliary System and Pancreas'
#  'Ear, Nose, Mouth, Throat and Craniofacial Diseases and Disorders'
#  'Diseases and Disorders of the Circulatory System'
#  'Diseases and Disorders of the Nervous System'
#  'Diseases and Disorders of Blood, Blood Forming Organs and Immunological Disorders'
#  'Diseases and Disorders of the Kidney and Urinary Tract'
#  'Endocrine, Nutritional and Metabolic Diseases and Disorders'
#  'Diseases and Disorders of the Skin, Subcutaneous Tissue and Breast'
#  'Mental Diseases and Disorders'
#  'Rehabilitation, Aftercare, Other Factors Influencing Health Status and Other Health Service Contacts'
#  'Alcohol/Drug Use and Alcohol/Drug Induced Organic Mental Disorders'
#  'Lymphatic, Hematopoietic, Other Malignancies, Chemotherapy and Radiotherapy'
#  'Diseases and Disorders of the Male Reproductive System'
#  'Multiple Significant Trauma'
#  'Poisonings, Toxic Effects, Other Injuries and Other Complications of Treatment'
#  'Newborns and Other Neonates with Conditions Originating in the Perinatal Period'
#  'Human Immunodeficiency Virus Infections' 'Burns'
#  'Diseases and Disorders of the Eye']
#
#
# There are 2 different values
#
# ['N' 'Y']

# %%
data.head()
# Out:
#      Health_Service_Area Hospital_County  Operating_Certificate_Number  \
# 3310          Western NY        Allegany                      228000.0
# 3311          Western NY        Allegany                      228000.0
# 3312          Western NY        Allegany                      228000.0
# 3316          Western NY        Allegany                      228000.0
# 3335          Western NY        Allegany                      228000.0
#
#       Facility_Id                                      Facility_Name  \
# 3310         39.0  Memorial Hosp of Wm F & Gertrude F Jones A/K/A...
# 3311         39.0  Memorial Hosp of Wm F & Gertrude F Jones A/K/A...
# 3312         39.0  Memorial Hosp of Wm F & Gertrude F Jones A/K/A...
# 3316         39.0  Memorial Hosp of Wm F & Gertrude F Jones A/K/A...
# 3335         39.0  Memorial Hosp of Wm F & Gertrude F Jones A/K/A...
#
#      Age_Group Zip_Code_-_3_digits Gender        Race          Ethnicity  \
# 3310  50 to 69                 147      M       White  Not Span/Hispanic
# 3311  50 to 69                 148      F       White  Not Span/Hispanic
# 3312  30 to 49                 148      F       White  Not Span/Hispanic
# 3316  18 to 29                 148      F  Other Race  Not Span/Hispanic
# 3335  18 to 29                 148      F       White  Not Span/Hispanic
#
#          ...      Payment_Typology_2 Payment_Typology_3  \
# 3310     ...                Medicare           Medicaid
# 3311     ...                Medicare           Self-Pay
# 3312     ...                Self-Pay           Self-Pay
# 3316     ...                Self-Pay           Self-Pay
# 3335     ...                Self-Pay           Self-Pay
#
#      Attending_Provider_License_Number  Operating_Provider_License_Number  \
# 3310                          187816.0                           187816.0
# 3311                          187816.0                           187816.0
# 3312                          196988.0                           196988.0
# 3316                          114112.0                           114112.0
# 3335                          196988.0                           196988.0
#
#       Other_Provider_License_Number Birth_Weight  Abortion_Edit_Indicator  \
# 3310                       210775.0            0                        N
# 3311                       210775.0            0                        N
# 3312                       247101.0            0                        N
# 3316                     60001564.0            0                        N
# 3335                       247101.0            0                        N
#
#      Emergency_Department_Indicator  Total_Charges Total_Costs
# 3310                              N       26102.75    14423.13
# 3311                              N       16951.25     7886.33
# 3312                              N       10452.75     5112.96
# 3316                              N       12677.75     7475.38
# 3335                              N       11540.75     6109.86
#
# [5 rows x 37 columns]

# %%
cleanups = {"Gender" : {"M": 0, "F":1},
          "Emergency_Department_Indicator": {"N":0, "Y":1},
          "Abortion_Edit_Indicator": {"N":0, "Y":1}}
data.replace(cleanups, inplace=True)
data.head()
# Out:
#      Health_Service_Area Hospital_County  Operating_Certificate_Number  \
# 3310          Western NY        Allegany                      228000.0
# 3311          Western NY        Allegany                      228000.0
# 3312          Western NY        Allegany                      228000.0
# 3316          Western NY        Allegany                      228000.0
# 3335          Western NY        Allegany                      228000.0
#
#       Facility_Id                                      Facility_Name  \
# 3310         39.0  Memorial Hosp of Wm F & Gertrude F Jones A/K/A...
# 3311         39.0  Memorial Hosp of Wm F & Gertrude F Jones A/K/A...
# 3312         39.0  Memorial Hosp of Wm F & Gertrude F Jones A/K/A...
# 3316         39.0  Memorial Hosp of Wm F & Gertrude F Jones A/K/A...
# 3335         39.0  Memorial Hosp of Wm F & Gertrude F Jones A/K/A...
#
#      Age_Group Zip_Code_-_3_digits  Gender        Race          Ethnicity  \
# 3310  50 to 69                 147       0       White  Not Span/Hispanic
# 3311  50 to 69                 148       1       White  Not Span/Hispanic
# 3312  30 to 49                 148       1       White  Not Span/Hispanic
# 3316  18 to 29                 148       1  Other Race  Not Span/Hispanic
# 3335  18 to 29                 148       1       White  Not Span/Hispanic
#
#          ...      Payment_Typology_2 Payment_Typology_3  \
# 3310     ...                Medicare           Medicaid
# 3311     ...                Medicare           Self-Pay
# 3312     ...                Self-Pay           Self-Pay
# 3316     ...                Self-Pay           Self-Pay
# 3335     ...                Self-Pay           Self-Pay
#
#      Attending_Provider_License_Number  Operating_Provider_License_Number  \
# 3310                          187816.0                           187816.0
# 3311                          187816.0                           187816.0
# 3312                          196988.0                           196988.0
# 3316                          114112.0                           114112.0
# 3335                          196988.0                           196988.0
#
#       Other_Provider_License_Number Birth_Weight  Abortion_Edit_Indicator  \
# 3310                       210775.0            0                        0
# 3311                       210775.0            0                        0
# 3312                       247101.0            0                        0
# 3316                     60001564.0            0                        0
# 3335                       247101.0            0                        0
#
#      Emergency_Department_Indicator  Total_Charges Total_Costs
# 3310                              0       26102.75    14423.13
# 3311                              0       16951.25     7886.33
# 3312                              0       10452.75     5112.96
# 3316                              0       12677.75     7475.38
# 3335                              0       11540.75     6109.86
#
# [5 rows x 37 columns]
